# %%
#rebuild tensorflow with comiler flags
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Import necessary libraries and packages
import pandas as pd
from pandas import DataFrame
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import warnings
from math import exp
from numpy import log
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import statsmodels.api as sm
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow import keras
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from tensorflow.python.keras.metrics import Metric

import plotly.graph_objs as go
from plotly.subplots import make_subplots
import seaborn as sns
# Preferred settings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100)

# %%
#Import Footprint and Biocapacity data
data = pd.read_csv('../Data/footprint-nfba-2019/data/nfa_2019_public_data.csv')
df = data

#Observe data shape and head
print(df.shape)
df.head(10)
# Out:
# (72186, 12)
#    country  year  country_code        record     crop_land   grazing_land  \
# 0  Armenia  1992             1    AreaPerCap  1.402924e-01       0.199546
# 1  Armenia  1992             1     AreaTotHA  4.830000e+05  687000.000000
# 2  Armenia  1992             1  BiocapPerCap  1.598044e-01       0.135261
# 3  Armenia  1992             1  BiocapTotGHA  5.501762e+05  465677.972200
# 4  Armenia  1992             1  EFConsPerCap  3.875102e-01       0.189462
# 5  Armenia  1992             1  EFConsTotGHA  1.334124e+06  652282.314700
# 6  Armenia  1992             1  EFProdPerCap  1.598044e-01       0.135261
# 7  Armenia  1992             1  EFProdTotGHA  5.501762e+05  465677.972200
# 8  Armenia  1993             1    AreaPerCap  1.465909e-01       0.204573
# 9  Armenia  1993             1     AreaTotHA  4.930000e+05  688000.000000
#
#    forest_land  fishing_ground  built_up_land        carbon         total  \
# 0  0.097188051        0.036888       0.029320  0.000000e+00  5.032351e-01
# 1       334600   127000.000000  100943.000800  0.000000e+00  1.732543e+06
# 2  0.084003213        0.013742       0.033398  0.000000e+00  4.262086e-01
# 3  289207.1078    47311.551720  114982.279300  0.000000e+00  1.467355e+06
# 4     1.26E-06        0.004165       0.033398  1.114093e+00  1.728629e+00
# 5  4.328086713    14338.728980  114982.279300  3.835610e+06  5.951342e+06
# 6            0        0.001266       0.033398  1.074631e+00  1.404360e+00
# 7            0     4358.142036  114982.279300  3.699750e+06  4.834944e+06
# 8  0.099432069        0.037763       0.029320  0.000000e+00  5.176788e-01
# 9       334400   127000.000000   98605.697630  0.000000e+00  1.741006e+06
#
#   qscore
# 0     3A
# 1     3A
# 2     3A
# 3     3A
# 4     3A
# 5     3A
# 6     3A
# 7     3A
# 8     3A
# 9     3A

# %% [markdown]
# # Data Cleaning and Preprocessing

# %%
#check random data chunk
data.sample(5)
# Out:
#                         country  year  country_code        record  crop_land  \
# 69992                    Zambia  2000           251  EFProdPerCap   0.145465
# 41858                  Mongolia  1999           141  BiocapPerCap        NaN
# 23310                   Germany  1996            79  EFProdPerCap   0.687603
# 1386                    Algeria  1997             4  BiocapPerCap        NaN
# 65504  United States of America  1964           231  EFProdPerCap   1.117796
#
#        grazing_land  forest_land  fishing_ground  built_up_land    carbon  \
# 69992      0.193387     0.348976        0.009831       0.023189  0.064519
# 41858           NaN          NaN             NaN            NaN       NaN
# 23310      0.058139  0.319104695        0.032292       0.117286  3.952856
# 1386            NaN          NaN             NaN            NaN       NaN
# 65504      0.488553  1.085434878        0.069381       0.037727  5.744175
#
#            total qscore
# 69992   0.785368     3A
# 41858  19.236741     2A
# 23310   5.167281     3A
# 1386    0.488221     2A
# 65504   8.543067     3A

# %% [markdown]
# We check the data-type of each column is of preferred data type

# %%
data.dtypes
# Out:
# country            object
# year                int64
# country_code        int64
# record             object
# crop_land         float64
# grazing_land      float64
# forest_land        object
# fishing_ground    float64
# built_up_land     float64
# carbon            float64
# total             float64
# qscore             object
# dtype: object

# %% [markdown]
# The Data type of the "country", "record", and "QScore" columns are of object type, which should be converted to String to be accessed or modified

# %%
#modify the datatype of country, record and QScore columns
data["country"] = data['country'].astype('string')
data["record"] = data['record'].astype('string')
data["qscore"] = data['qscore'].astype('string')

data.dtypes
# Out:
# country            string
# year                int64
# country_code        int64
# record             string
# crop_land         float64
# grazing_land      float64
# forest_land        object
# fishing_ground    float64
# built_up_land     float64
# carbon            float64
# total             float64
# qscore             string
# dtype: object

# %% [markdown]
# In order to carry out accurate pre-processing we have to first find out the number of Null Values in each column.

# %%
#check null values
print(data.isna().sum())
print(data.shape)
# Out:
# country               0
# year                  0
# country_code          0
# record                0
# crop_land         20472
# grazing_land      20472
# forest_land       20472
# fishing_ground    20473
# built_up_land     20473
# carbon            20473
# total                 9
# qscore                1
# dtype: int64
# (72186, 12)

# %% [markdown]
# Since Entire rows contain NULL values, we have removed all such rows to clean our data. Rows were removed by removing rows that had less than 7 non-NULL cells.

# %%
#drop null values
df = data.dropna(axis=0, thresh=7)
#compression_opts = dict(method='zip', archive_name='out.csv')  
#df.to_csv('out.zip', index=False, compression=compression_opts) 

print(df.shape)
print(df.isna().sum())
# Out:
# (51714, 12)
# country           0
# year              0
# country_code      0
# record            0
# crop_land         0
# grazing_land      0
# forest_land       0
# fishing_ground    1
# built_up_land     1
# carbon            1
# total             1
# qscore            1
# dtype: int64

# %% [markdown]
# ## Ecological Footprint

# %%
#Only include India's Ecological Footprint data 
df_India = df.loc[(df['country'] == "India") & (df['record'] == "BiocapPerCap") ,['year','total']]
df_India = df_India[['year', 'total']]
df_India.head(10)
# Out:
#        year     total
# 28058  1961  0.492369
# 28066  1962  0.486902
# 28074  1963  0.474522
# 28082  1964  0.471100
# 28090  1965  0.443812
# 28098  1966  0.434675
# 28106  1967  0.459217
# 28114  1968  0.470072
# 28122  1969  0.474293
# 28130  1970  0.492222

# %%
#Convert year to index
df_India.set_index('year', inplace=True)

#Convert year to DateTime object
df_India.index = pd.to_datetime(df_India.index, format='%Y')

# %%
#observe updated df
#df_India.head()
df_India.sample(5)
# Out:
#                total
# year
# 1992-01-01  0.456813
# 1995-01-01  0.448806
# 1987-01-01  0.419076
# 1981-01-01  0.443597
# 1978-01-01  0.468687

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# **Reviewing plots of the density of observations can provide further insight into the structure of the data**

# %%
#observe density
pyplot.figure(1)
pyplot.subplot(211)
df_India.total.hist()
pyplot.subplot(212)
df_India.total.plot(kind='kde')
pyplot.show()

# %% [markdown]
# From the above graphs we can observe,
# - The distribution is not perfectly Gausian (normal distribution)
# - The distribution in right shifted
# - Transformations might be useful prior to modelling

# %% [markdown]
# Reviewing Box plot of emissions over decades provides insight into the trend and seasonality of the data

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.boxplot(df_India.total.index.year // 10 * 10, df_India.total, ax=ax)
# Out:
# <AxesSubplot:xlabel='year', ylabel='total'>

# %% [markdown]
# From the above plot we can observe,
# - Median values across decade confirms an irregular downward trend
# - changing trend in Biocapacity

# %% [markdown]
# **Distribution and Normality Test**

# %%
#observe distribution and normality
sns.distplot(df_India.total);
stats.normaltest(df_India.total)
print('Kurtosis of normal distribution {}'.format(stats.kurtosis(df_India.total)))
print( 'Skewness of normal distribution {}'.format(stats.skew(df_India.total)))
# Out:
# Kurtosis of normal distribution -0.081021880941051
# Skewness of normal distribution -0.027771117572409097

# %% [markdown]
# > - Kurtosis describes heaviness of the tails of distribution
#     - Normal Distribution has a kurtosis of 0 (mesokurtic). A Positive value  shows us that the data has heavy-tails. A neagtive value (as observed) mean that data has ligh tails
#
#
# > - Skewness
#     - if < -1 / > 1 -distribution is highly skewed.
#     - if -1 < skew < - 0.5 / 0.5 < skew < 1 - distribution is moderately skewed.
#     - if -0.5 < skew < 0.5 - distribution is approximately similar. (as observed)

# %%
#observe distribution
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
df_India.total.hist(bins=50,edgecolor='black', grid=False)
plt.title('Biocapacity Per Capita')

plt.subplot(1,2,2)
stats.probplot(df_India.total, plot=plt);
#print("Skewness: %f" % df['Consumption'].skew())
#print("Kurtosis: %f" % df['Consumption'].kurt())
df_India.describe().transpose()
# Out:
#        count      mean       std       min      25%       50%       75%  \
# total   56.0  0.447746  0.021148  0.393677  0.43433  0.449431  0.457414
#
#             max
# total  0.492369

# %% [markdown]
# Normal probability plot shows that data set has irregular distribution, with trends

# %%
#observe trend and seasonality
from pylab import rcParams
decomposition = sm.tsa.seasonal_decompose(df_India.total, model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(df_India.total, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# With Observations from decomposing we observe,
# - seasonal characteristics of Data
# - Constant residual
# - Inconsistent Trend

# %% [markdown]
# ### Exponential Smoothing

# %% [markdown]
# #### Naive Model Using Holt-Winter's Method

# %% [markdown]
# We start with Holt's method, which does not account for seasonality

# %%
# Train-test split
df_es = df_India
x = df_es.index
y = df_es['total']

estrain = df_es.loc[:'2011-01-01']
estest = df_es.loc['2011-01-01':]

df_es.shape
# Out:
# (56, 1)

# %% [markdown]
# **Holt's Method - Double Exponential Smoothening**
#
# using trend as additive

# %%
#apply double exponential smoothening
model_des = ExponentialSmoothing(estrain.total,trend = 'add')
model_des_fit = model_des.fit()
estrain['DES_model'] = model_des_fit.fittedvalues.shift(-1)

# %%
# observe the DES model against the original data
estrain[['total','DES_model']].plot(legend = True)
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# From above, we observe Double Exponential Smoothening results looks inconsistent

# %% [markdown]
# **Holt-Winter's Method - Triple Exponential Smoothening**

# %% [markdown]
# Using trend and seasonality as multiplicative. Setting the number of seasonal_periods as 12 (yearly)

# %%
model_tes = ExponentialSmoothing(estrain.total,trend = 'add', seasonal = 'add', seasonal_periods=12)
model_tes_fit = model_tes.fit()
estrain['TES_model'] = model_tes_fit.fittedvalues.shift(-1)

# %%
# observe the DES model against the original data
ax = estrain.total.plot(label='observed', color='royalblue', legend=True)
estrain.TES_model.plot(ax=ax, label='TES', color='orangered', legend=True )

ax.set_xlabel('Year', size=15)
ax.set_ylabel('Biocapacity Per Capita \n', size=10)
ax.set_title('Real vs Predicted Biocapacity Per Capita \n', size=15)

plt.legend()
plt.show()

# %% [markdown]
# Lets observe Results of Double and Triple Exponential Smoothening

# %%
# observe the DES model against the original data
estrain[['total','DES_model','TES_model']].plot(legend = True)
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# From above, we observe Triple Exponential Smoothening results looks reasonably well performing than Double Exponential Smoothening

# %% [markdown]
# **Double and Triple Exponential Models : Forecasts**

# %% [markdown]
# Lets forecast on test set of data

# %%
#forecast on test set
test_des = model_des_fit.forecast(6)
test_tes = model_tes_fit.forecast(6)

# %%
# Plotting Test predictions against the test set
estest['total'].plot(legend = True)
test_des.plot(legend = True, label = "Double Exponential Smoothening")
test_tes.plot(legend = True, label = "Triple Exponential Smoothening")
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# #### Evaluate

# %%
#evaluate mse
des_mse = mean_squared_error(estest.total, test_des)
tes_mse = mean_squared_error(estest.total, test_tes)

print("RMSE for the Double Exponential Smoothening Model : ", round(np.sqrt(des_mse),3))
print("RMSE for the Triple Exponential Smoothening Model : ", round(np.sqrt(tes_mse),3))
# Out:
# RMSE for the Double Exponential Smoothening Model :  0.021
# RMSE for the Triple Exponential Smoothening Model :  0.013

# %%
from sklearn.metrics import mean_absolute_error
#Create a function to calculate AIC for our models
def MAE(test):
    return mean_absolute_error(estest.total, test)

print(" MAE for the Double Exponential Smoothening Model : ", round(MAE(test_des),3))
print(" MAE for the Triple Exponential Smoothening Model : ", round(MAE(test_tes),3))
# Out:
#  MAE for the Double Exponential Smoothening Model :  0.018
#  MAE for the Triple Exponential Smoothening Model :  0.011

# %%
#write a function to calculate MAPE value
def MAPE(test): 
    return np.mean(np.abs((estest.total - test) / estest.total)) * 100

print(" MAPE for the Double Exponential Smoothening Model : ", round(MAPE(test_des),3))
print(" MAPE for the Triple Exponential Smoothening Model : ", round(MAPE(test_tes),3))
# Out:
#  MAPE for the Double Exponential Smoothening Model :  3.479
#  MAPE for the Triple Exponential Smoothening Model :  1.837

# %% [markdown]
# From above results, we can observe
#
# >- RMSE of Holt-Winter's (TES) is **lesser** than DES
# >- MAE of Holt-Winter's (TES) is **lesser** than DES
# >- MAPE of Holt-Winter's (TES) is **lesser** than DES, means marginally better accuracy
#
#
# ***TES performs well for predicting data post 2011, so it will be used for forecasting***

# %% [markdown]
# #### Future Forecasts

# %%
test_tes_20 = model_tes_fit.forecast(20)
test_tes_20[6:20]
# Out:
# 2018-01-01    0.437026
# 2019-01-01    0.447330
# 2020-01-01    0.436734
# 2021-01-01    0.432474
# 2022-01-01    0.428437
# 2023-01-01    0.431939
# 2024-01-01    0.429179
# 2025-01-01    0.430307
# 2026-01-01    0.415282
# 2027-01-01    0.419567
# 2028-01-01    0.418703
# 2029-01-01    0.421681
# 2030-01-01    0.425204
# 2031-01-01    0.435508
# Freq: AS-JAN, dtype: float64

# %%
# Plotting Test predictions against the test set
estest['total'].plot(legend = True)
test_tes_20.plot(legend = True, label = "Triple Exponential Smoothening")
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# We've achieved a exponentially smoothened forecast, lets compare this with ARIMA models.
#
# Naive Holt's and Holt-Winter's exponential smoothening works with non-stationary data, But for ARIMA models we need to check stationarity to know the order of differnecing required inorder to obtain better results
#
# Lets check stationarity and process the data

# %% [markdown]
# ### Check for Stationarity
# - Any time series data is said to be stationary if its statistical properties such as mean, variance remains constant over time
#
# lets observe the properties

# %%
#Visualize India's CO2 emissions since 1900,
#including 5-year rolling mean and rolling standard deviation

roll_mean = df_India.rolling(window=5, center=False).mean()
roll_std = df_India.rolling(window=5, center=False).std()

plt.plot(df_India, color='mediumseagreen', label='Original')
plt.plot(roll_mean, color='mediumblue', label='Rolling Mean')
plt.plot(roll_std, color='orangered', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.xlabel('Year')
plt.ylabel('Biocapacity')
plt.show(block=False)

# %%
#perform Dickey-Fuller test
test_result = adfuller(df_India.total[1:-1])
df_result = pd.Series(test_result[0:5], index=['ADF Statistic','p-value','#Lags Used','No. of Observations Used', 'Critical Values'])
df_result
# Out:
# ADF Statistic                                                       -3.800851
# p-value                                                              0.002899
# #Lags Used                                                                  0
# No. of Observations Used                                                   53
# Critical Values             {'1%': -3.560242358792829, '5%': -2.9178502070...
# dtype: object

# %% [markdown]
# With p-value of 0.99 ( >0.05), we cannot reject that null hypothesis that this is non-stationary.
#
# we also can see that our ADF statistic value (3.98) is greater than tha value -3.58 at 1%. This suggests that we cannot reject the null hypothesis with a significance of less than 1%, i.e. a low probability that the result is a statistical fluke. The process has unit root and in turn the timer series is un-stationary or does have time-dependent structure
#
# As we observe the data is non-stationary, this cannot be fit for autocorrelation analysis as ACF and PACF assumes data stationary. Lets remedy this below before fitting our model.

# %% [markdown]
# ## Addressing Trends and Stationarity
#
# lets observe stationarity plotting rolling statistics and address the stationarity

# %% [markdown]
# ### Log Transformation

# %%
#apply log transformation
#Create new dataframe that contains the logged values of the original one
log_India = log(df_India)

#Visualize Logged data, including 5-year rolling mean and standard deviation
roll_mean_log = log_India.rolling(window=5, center=False).mean()
roll_std_log = log_India.rolling(window=5, center=False).std()

plt.plot(log_India, color='mediumseagreen', label='Original')
plt.plot(roll_mean_log, color='mediumblue', label='Rolling Mean')
plt.plot(roll_std_log, color='orangered', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation, Logged Data')
plt.xlabel('Year')
plt.ylabel('Logged Biocapacity')
plt.show(block=False)

# %%
#perform Dickey-Fuller test for log tranformed data
test_result = adfuller(log_India.total[1:-1])
df_log_result = pd.Series(test_result[0:5], index=['ADF Statistic','p-value','#Lags Used','No. of Observations Used', 'Critical Values'])
df_log_result
# Out:
# ADF Statistic                                                       -3.807371
# p-value                                                              0.002833
# #Lags Used                                                                  0
# No. of Observations Used                                                   53
# Critical Values             {'1%': -3.560242358792829, '5%': -2.9178502070...
# dtype: object

# %% [markdown]
# With p-value of 0.002 (<0.05), we reject that null hypothesis. This data does not have unit root and is stationary.
#
# Based on real p-value of 0.002, we have achieved stationarity by Log Transofrmation. Lets check by differencing to check if the data needs d parameter in ARIMA model

# %% [markdown]
# ### Differencing

# %%
#create dataframe for differencing
log_diff = log_India.diff().dropna().rename(index=str, columns={"total":"Differenced Observations"})

#Visualize differenced data, inclusing 5-year rolling mean and standard deviation
roll_mean_diff = log_diff.rolling(window=5, center=False).mean()
roll_std_diff = log_diff.rolling(window=5, center=False).std()

plt.plot(log_diff, color='mediumseagreen', label='Original')
plt.plot(roll_mean_diff, color='mediumblue', label='Rolling Mean')
plt.plot(roll_std_diff, color='orangered', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation, Differenced Data')
plt.xlabel('Differenced Year')
plt.ylabel('Differenced Biocapacity')
plt.show(block=False)

# %%
#perform Dickey-Fuller test for log-minus-rollmean data
diff_result = adfuller(log_diff['Differenced Observations'][1:-1])
df_diff_result = pd.Series(diff_result[0:4], index=['ADF Statistic','p-value','#Lags Used','No. of Observations Used'])
df_diff_result
# Out:
# ADF Statistic              -6.471143e+00
# p-value                     1.366213e-08
# #Lags Used                  1.000000e+00
# No. of Observations Used    5.100000e+01
# dtype: float64

# %% [markdown]
# With p-value of 1.366213e-08 (<0.05), we reject that null hypothesis. This data does not have unit root and is stationary.
#
# Based on real p-value of 1.366213e-08, we have achieved stationarity by 1st order differencing. We will keep this in count as we test d values in our ARIMA models

# %% [markdown]
# ## Modelling

# %% [markdown]
# We will create time series models on our original data considering the order of differencing required to attain stationarity

# %% [markdown]
# **ACF for Logged Data**

# %%
# observe ACF for logged data
plot_acf(df_India[:-1], alpha=.05, lags=20);

# %% [markdown]
# **PACF for Logged Data**

# %%
# PACF for original data
plot_pacf(df_India[:-1], alpha=.05, lags=20);

# %% [markdown]
# From the above ACF and PACF for our original data, we can observe
#
# > - A series that has a wave form of Autocorrelation and Significant at each lag  𝑝  / Cuts off after lag  𝑝 - AR  𝑝   model
#
# > - Our data displayes an AR signature since ACF diminishes gradually and the PACF uctts off sharply at lag 2, showing string correlation. This tells us we would expect to have atleast one AR parameter.
#
# > -  When instantiating an ARIMA model, we expect a relatively large number of MA terms due to large number of significant ACF points and relatively smaller AR terms due to small number of significant PACF points.

# %% [markdown]
# **ARIMA Model for Original Data**

# %%
#building the auto-arima model to compare our observed ordered
from pmdarima.arima import auto_arima
model = auto_arima(df_India, trace=True, error_action='ignore', suppress_warnings=True)
model.fit(df_India)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-288.970, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-284.538, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-286.676, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-288.241, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-286.291, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-289.265, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-288.670, Time=0.21 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-290.458, Time=0.15 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-292.395, Time=0.18 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-289.938, Time=0.22 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=-289.266, Time=0.23 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=-288.327, Time=0.27 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=-289.986, Time=0.12 sec
#
# Best model:  ARIMA(0,1,4)(0,0,0)[0] intercept
# Total fit time: 1.948 seconds
# ARIMA(order=(0, 1, 4), scoring_args={}, suppress_warnings=True)

# %%
# Instantiate model
mod014 = ARIMA(df_India[:-1], order=(0,1,4))

# Fit model
mod014_fit = mod014.fit()

# Observe summary statistics
print(mod014_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  total   No. Observations:                   55
# Model:                 ARIMA(0, 1, 4)   Log Likelihood                 146.789
# Date:                Mon, 25 Apr 2022   AIC                           -283.578
# Time:                        03:46:30   BIC                           -273.633
# Sample:                    01-01-1961   HQIC                          -279.743
#                          - 01-01-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4242      0.160     -2.655      0.008      -0.737      -0.111
# ma.L2         -0.0086      0.152     -0.057      0.955      -0.306       0.289
# ma.L3         -0.0108      0.177     -0.061      0.951      -0.358       0.336
# ma.L4         -0.3188      0.182     -1.752      0.080      -0.676       0.038
# sigma2         0.0003   5.59e-05      4.484      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 0.26
# Prob(Q):                              0.78   Prob(JB):                         0.88
# Heteroskedasticity (H):               1.08   Skew:                            -0.16
# Prob(H) (two-sided):                  0.87   Kurtosis:                         2.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Re-Fit Models to Train-Test Split Data

# %%
# Train-test split
x = df_India.index
y = df_India['total']

train = df_India.loc[:'2011-01-01']
test = df_India.loc['2011-01-01':]

x_train, x_test = train.index, test.index
y_train, y_test = train['total'], test['total']

# %%
y_test
# Out:
# year
# 2011-01-01    0.452325
# 2012-01-01    0.442001
# 2013-01-01    0.449335
# 2014-01-01    0.449548
# 2015-01-01    0.424334
# 2016-01-01    0.427524
# Name: total, dtype: float64

# %%
# 014  data
# Instantiate and fit model to train data
model014 = ARIMA(y_train[2:], order=(0,1,4)) #p,d,q
model014_fit = model014.fit()

#Prediction
pred014 = model014_fit.predict(start='1990-01-01', end='2016-01-01', dynamic=False)

# %% [markdown]
# ### Analyze Final Model

# %%
#Visualize resicudals
residuals = DataFrame(model014_fit.resid)
residuals.plot(color='royalblue')
plt.show()

# %%
#observe residuals/error distributions
residuals.describe()
# Out:
#                0
# count  49.000000
# mean    0.006596
# std     0.070135
# min    -0.046727
# 25%    -0.013351
# 50%    -0.001380
# 75%     0.007549
# max     0.474522

# %% [markdown]
# Based on the above, we observe that our model has minimal error with little bias, with a mean of approximately 0. Next, we observe a density plot of the residual error values, suggesting the errors ar gaussian, but may not be centered on zero

# %%
#check for linearlity
residuals = DataFrame(model014_fit.resid)
residuals.plot(kind='kde', color='royalblue')
plt.show()

# %% [markdown]
# Based on the above, we observe that our model is nearly linear, with mean of approximately 0. Next we observe the diagnostics to evaluate our model

# %%
#observe diagonstics
model014_fit.plot_diagnostics(figsize=(10,8))
plt.show()

# %% [markdown]
# In the top right plot, thw orangered line follows closely with the N(0,1) line. Where, N(0,1) is the standard notation for a normal distribution with mean 0 and standard deviation 1. This is a good indication thath the residuals are normally distributed. The forecast errors deviate a little bit from the straight line, indicating that the normal distribution is not a perfect model for the distribution of forecast errors, but it is not unreasonable.
#
# The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) follows the linear trend of the samples taken from a standard normal distribution. Again,this is a strong indication that the residuals are normally distributed.
#
# The residuals over time (top left plot) don't display any obvious seasonality and appear to be white noise. This is confirmed by the autocorrelation (i.e, correlation) plot on the bottom right, which shows that the time series residuals have low correlation with lagged versions of itself.

# %%
#observe predictions
pred_model014 = model014_fit.get_prediction(start='1990-01-01', end='2016-01-01', dynamic=False)
pred_ci = pred_model014.conf_int()
pred_ci.head(10)
# Out:
#             lower total  upper total
# 1990-01-01     0.430155     0.494307
# 1991-01-01     0.424792     0.488942
# 1992-01-01     0.417944     0.482093
# 1993-01-01     0.418414     0.482562
# 1994-01-01     0.418531     0.482677
# 1995-01-01     0.421788     0.485934
# 1996-01-01     0.417268     0.481413
# 1997-01-01     0.421237     0.485381
# 1998-01-01     0.417560     0.481704
# 1999-01-01     0.419370     0.483514

# %%
#observe real vs forecasted emissions values

#plot observed values
ax = df_India.plot(label='observed', color='royalblue', legend=True)

#plot predicted values
pred_model014.predicted_mean.plot(ax=ax, label='ARIMA', color='orangered', alpha=0.9, legend=True )

#add fill between lines, set axes labels and title
ax.fill_between(pred_ci.index,
               pred_ci.iloc[:, 0],
               pred_ci.iloc[:, 1],
               color='r', alpha=0.2)

ax.set_xlabel('Year', size=15)
ax.set_ylabel('Biocapacity Per Capita \n', size=12)
ax.set_title('Real vs Predicted Biocapacity Per Capita \n', size=15)

plt.legend()
plt.show()

# %% [markdown]
# The goal of developing the model is to get a good quality predictive power using dynamic forecast. That is, we use information from the timeseries up to a certain point, and after that point, forecasts are generated using values from historical time points

# %%
#get dynamic predictions
pred_dynamic = model014_fit.get_prediction(start='1990-01-01', end='2016-01-01', dynamic=True, full_results=True)
#get confidence Intervals
pred_dynamic_ci = pred_dynamic.conf_int()
pred_dynamic_ci.sample(10)
# Out:
#             lower total  upper total
# 2002-01-01     0.405854     0.497940
# 1997-01-01     0.408379     0.495414
# 1995-01-01     0.409432     0.494362
# 1996-01-01     0.408902     0.494891
# 2010-01-01     0.402079     0.501715
# 2000-01-01     0.406847     0.496946
# 2011-01-01     0.401627     0.502167
# 2007-01-01     0.403460     0.500334
# 2015-01-01     0.399858     0.503935
# 2009-01-01     0.402535     0.501259

# %%
#plot observed values
ax = df_India['1960-01-01':].plot(label='observed', color='royalblue')

#plot predicted values
pred_dynamic.predicted_mean.plot(ax=ax, label='Dynamic Forecast', color='orangered', alpha=0.9)

#add fill between lines, set axes labels and title
ax.fill_between(pred_dynamic_ci.index,
               pred_dynamic_ci.iloc[:, 0],
               pred_dynamic_ci.iloc[:, 1],
               color='r', alpha=0.3)

ax.fill_betweenx(ax.get_ylim(),
                '1990-01-01',
                df_India.index[-1],
                alpha=0.2,
                zorder= -1)

ax.set_xlabel('Year', size=15)
ax.set_ylabel('Ecological Footprint Per Capita', size=12)
ax.set_title('Real vs Predicted Per Capita Ecological Footprint \n', size=15)

plt.legend()
plt.show()

# %% [markdown]
# **SARIMA Model**

# %%
#building the model
from pmdarima.arima import auto_arima
smodel = auto_arima(df_India, 
                   trace=True, 
                   error_action='ignore', 
                   suppress_warnings=True, 
                   seasonal=True, 
                   m=6, 
                   stepwise=True)
smodel_fit = smodel.fit(df_India)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[6] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(0,1,0)(0,0,0)[6] intercept   : AIC=-284.538, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[6] intercept   : AIC=-285.111, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,1)[6] intercept   : AIC=-286.800, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[6]             : AIC=-286.291, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[6] intercept   : AIC=-288.241, Time=0.06 sec
#  ARIMA(0,1,1)(1,0,0)[6] intercept   : AIC=-286.595, Time=0.10 sec
#  ARIMA(0,1,1)(1,0,1)[6] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(1,1,1)(0,0,0)[6] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,0)[6] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,0)[6] intercept   : AIC=-286.676, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[6] intercept   : AIC=-289.265, Time=0.05 sec
#  ARIMA(1,1,2)(1,0,0)[6] intercept   : AIC=-287.625, Time=0.14 sec
#  ARIMA(1,1,2)(0,0,1)[6] intercept   : AIC=-286.932, Time=0.10 sec
#  ARIMA(1,1,2)(1,0,1)[6] intercept   : AIC=-287.006, Time=0.35 sec
#  ARIMA(2,1,2)(0,0,0)[6] intercept   : AIC=-288.970, Time=0.17 sec
#  ARIMA(1,1,3)(0,0,0)[6] intercept   : AIC=-288.670, Time=0.16 sec
#  ARIMA(0,1,3)(0,0,0)[6] intercept   : AIC=-290.458, Time=0.14 sec
#  ARIMA(0,1,3)(1,0,0)[6] intercept   : AIC=-287.165, Time=0.20 sec
#  ARIMA(0,1,3)(0,0,1)[6] intercept   : AIC=-289.455, Time=0.24 sec
#  ARIMA(0,1,3)(1,0,1)[6] intercept   : AIC=-288.287, Time=0.31 sec
#  ARIMA(0,1,4)(0,0,0)[6] intercept   : AIC=-292.395, Time=0.19 sec
#  ARIMA(0,1,4)(1,0,0)[6] intercept   : AIC=-289.619, Time=0.26 sec
#  ARIMA(0,1,4)(0,0,1)[6] intercept   : AIC=-290.260, Time=0.42 sec
#  ARIMA(0,1,4)(1,0,1)[6] intercept   : AIC=-287.879, Time=0.35 sec
#  ARIMA(1,1,4)(0,0,0)[6] intercept   : AIC=-289.938, Time=0.19 sec
#  ARIMA(0,1,5)(0,0,0)[6] intercept   : AIC=-289.266, Time=0.22 sec
#  ARIMA(1,1,5)(0,0,0)[6] intercept   : AIC=-288.327, Time=0.26 sec
#  ARIMA(0,1,4)(0,0,0)[6]             : AIC=-289.986, Time=0.14 sec
#
# Best model:  ARIMA(0,1,4)(0,0,0)[6] intercept
# Total fit time: 5.382 seconds

# %%
# Train-test split
xs = df_India.index
ys = df_India['total']

strain = df_India.loc[:'2011-01-01']
stest = df_India.loc['2011-01-01':]

x_strain, x_stest = strain.index, stest.index
y_strain, y_stest = strain['total'], stest['total']

# %%
#instatiate SARIMA Model
smodel = ARIMA(y_strain[2:],order=(0,1,4),seasonal_order=(0,0,0,6))
smodel_fit = smodel.fit()

#Prediction
pred_mods = smodel_fit.predict(start='1990-01-01', end='2020-01-01', dynamic=False)

# %%
#observe predictions
pred_smodel = smodel_fit.get_prediction(start='1990-01-01', end='2020-01-01', dynamic=False)
pred_sci = pred_smodel.conf_int()
pred_sci.sample(10)
# Out:
#             lower total  upper total
# 2009-01-01     0.400780     0.464923
# 1991-01-01     0.424792     0.488942
# 2020-01-01     0.392765     0.480808
# 2017-01-01     0.394334     0.479239
# 2000-01-01     0.420714     0.484857
# 2019-01-01     0.393281     0.480291
# 2015-01-01     0.395413     0.478160
# 1995-01-01     0.421788     0.485934
# 2008-01-01     0.406801     0.470944
# 2007-01-01     0.390232     0.454375

# %%
#observe real vs forecasted emissions values

#plot observed values
ax = df_India['1950-01-01':].plot(label='observed', color='royalblue')

#plot predicted values
pred_smodel.predicted_mean.plot(ax=ax, label='One-Step Forecast', color='orangered', alpha=0.5)

#add fill between lines, set axes labels and title
ax.fill_between(pred_sci.index,
               pred_sci.iloc[:, 0],
               pred_sci.iloc[:, 1],
               color='r', alpha=0.2)

ax.set_xlabel('Year', size=15)
ax.set_ylabel('Biocapacity', size=12)
ax.set_title('Real vs Predicted Biocapacity Per Capita', size=15)

plt.legend()
plt.show()

# %% [markdown]
# ### Evaluate Models

# %%
#evaluate mse
#Create a function to calculate RMSE for non-logged data
def RMSE(pred, test):
    return np.sqrt(((pred - y_test)**2).mean())

print("RMSE for the ARIMA Model : ", round(RMSE(pred014['2011-01-01':], y_test),5))
print("RMSE for the SARIMA Model : ", round(RMSE(pred_mods['2011-01-01':], y_stest),5))
#print("RMSE for the ARIMA Model : ", RMSE_reg(pred014, y_test))
#print("RMSE for the SARIMA Model : ", RMSE_reg(pred_mods, y_stest))
# Out:
# RMSE for the ARIMA Model :  0.01102
# RMSE for the SARIMA Model :  0.01102

# %% [markdown]
# Based on the above, we see that our model on our original data is much more predcitive.
# - We checked and we obsevred that SARIMA Model yields similar results to ARIMA Model, because of less-seasonal character of the data

# %% [markdown]
# ### Forecast Biocapacity Per Capita

# %%
#get forecast of 10 years stpes ahead in future
forecast2030 = model014_fit.get_forecast(steps=20)
#get confidence Intervals
forecast2030_ci = forecast2030.conf_int()
forecast2030_ci.tail(10)
# Out:
#             lower total  upper total
# 2022-01-01     0.391749     0.481824
# 2023-01-01     0.391249     0.482323
# 2024-01-01     0.390755     0.482817
# 2025-01-01     0.390267     0.483306
# 2026-01-01     0.389783     0.483790
# 2027-01-01     0.389304     0.484269
# 2028-01-01     0.388830     0.484743
# 2029-01-01     0.388361     0.485212
# 2030-01-01     0.387896     0.485677
# 2031-01-01     0.387435     0.486137

# %%
#plot observed values
ax = df_India['1961-01-01':].plot(label='observed', color='royalblue')

#plot Forecast values
forecast2030.predicted_mean.plot(ax=ax, label='Forecast', color='orangered', alpha=0.9)

#add fill between lines, set axes labels and title
ax.fill_between(forecast2030_ci.index,
               forecast2030_ci.iloc[:, 0],
               forecast2030_ci.iloc[:, 1],
               color='g', alpha=0.3)

ax.set_xlabel('Year', size=15)
ax.set_ylabel('Biocapactiy Per Capita', size=12)
ax.set_title('Future Forecast Biocapacity Per Capita \n', size=15)

plt.legend()
plt.show()

# %% [markdown]
# **Comparison**
#
# Lets compare and observe the predicts of ARIMA and Holt-Winter's models

# %%
#plot observed values
ax = df_India['1951-01-01':].plot(label='observed', color='royalblue', legend=True)

#plot predicted values
#ARIMA Model
pred_model014.predicted_mean.plot(ax=ax, label='ARIMA', color='green', alpha=0.9, legend=True)
#Holt-Winter's TES
test_tes_pred = model_tes_fit.predict(start='1990-01-01', end='2016-01-01')
test_tes_pred.plot(ax=ax, label='Holt-Winters TES', color='red', alpha=0.9, legend = True)

ax.set_xlabel('Year', size=15)
ax.set_ylabel('Biocapacity Per Capita \n', size=12)
ax.set_title('Real vs Predicted Biocapacity Per Capita (by 2030) \n', size=15)

plt.legend()
plt.show()

# %% [markdown]
# Lets compare and observe the forecasts of ARIMA and Holt-Winter's models

# %%
#plot Forecast values of ARIMA
ax = forecast2030.predicted_mean.plot( label='ARIMA', color='orangered', alpha=0.9, legend = True)

#plot Forecast values of Holt-Winter's
test_tes_20.plot(ax = ax, label = "Holt-Winter's TES", color='green', alpha=0.9,legend = True)

ax.set_xlabel('Year', size=15)
ax.set_ylabel('Biocapacity Per Capita \n', size=12)
ax.set_title('Future Forecast Biocapactiy ARIMA vs TES \n', size=15)

plt.legend()
plt.show()

# %% [markdown]
# #### Comparison Evaluation

# %%
#evaluate RMSE for ARIMA and Holt-Winter's Model
print("RMSE for the ARIMA Model : ", round(RMSE(pred014, y_test),3))
print("RMSE for the Holt-Winter's Model : ", round(np.sqrt(tes_mse),3))
# Out:
# RMSE for the ARIMA Model :  0.011
# RMSE for the Holt-Winter's Model :  0.013

# %%
#evaluate MAE for ARIMA and Holt-Winter's Model
print("MAE for the ARIMA Model : ", round(MAE(pred014['2011-01-01':]),4))
print("MAE for the Holt-Winter's Model : ", round(MAE(test_tes),4))
# Out:
# MAE for the ARIMA Model :  0.0097
# MAE for the Holt-Winter's Model :  0.0107

# %%
#evaluate MAPE for ARIMA and Holt-Winter's Model
print(" MAPE for the ARIMA Model : ", round(MAPE(pred014['2011-01-01':]),3))
print(" MAPE for the Holt-Winter's Model : ", round(MAPE(test_tes),3))
# Out:
#  MAPE for the ARIMA Model :  2.196
#  MAPE for the Holt-Winter's Model :  1.837

# %% [markdown]
# From above we observe,
#
# >- RMSE of Holt-Winter's (TES) is **Higher** than ARIMA
# >- MAE of Holt-Winter's (TES) is **Higher** than ARIMA
# >- But MAPE of Holt-Winter's (TES) is **lesser** than ARIMA, means marginally better accuracy
#
# >- Observing  the forecast graphs, we can Observe Holt-winter's provide accurate forecast trends as it smoothens with the trend and ARIMA differenced the data with order 1

# %% [markdown]
# ### LSTM Model

# %% [markdown]
# **Reporducibility** is extremely important as the parameter makes sure that when code is re-run, produces similar results

# %%
ax = df_India.plot(label='', color='royalblue', alpha=0.9, legend = True)
ax.set_xlabel('Year', size=15)
ax.set_ylabel('Biocapacity per capita (gha) \n', size=12)
ax.set_title('Biocapacity of India', size=12)

plt.legend()
plt.show()

# %%
#fix random seed for reproducibility
np.random.seed(42)

# %%
# Filter the target column from dataset and convert the dataframe to numpy
data = df_India['total']
dataset = df_India.values
dataset = dataset.astype('float32')

# %%
dataset.shape
# Out:
# (56, 1)

# %% [markdown]
# **Normalize Input**
#
# As with other deep learning problems, we can help neural network learn more rapidly by normalizing the inputs between 0 and 1. We will use `MinMaxScaler` for normalizing the input

# %%
#normalize
scaler = MinMaxScaler(feature_range=(0,1))
scaled_dataset = scaler.fit_transform(dataset) #try standard scaler

# %%
scaled_dataset.shape
# Out:
# (56, 1)

# %% [markdown]
# **Split intro train and test sets**

# %%
#split train-set
train_size = int(len(scaled_dataset)*0.90)
test_size = len(scaled_dataset) - train_size
train, test = scaled_dataset[0:train_size,:], scaled_dataset[train_size:len(scaled_dataset),:]
print(len(train), len(test))
# Out:
# 50 6

# %%
train.shape
# Out:
# (50, 1)

# %%
test.shape
# Out:
# (6, 1)

# %%
# Convert the data into a Supervised-learning data

x = []
y = []
look_back = 4
for i in range(look_back, len(train)):
    x.append(train[i-look_back:i, 0])
    y.append(train[i, 0])

# Converting into numpy sequences to train the LSTM model
trainX, trainY = np.array(x), np.array(y)

# %% [markdown]
# LSTM network should be fed with input data (X) with a specific array structure of form [Sample, time steps, features]
#
# lets restructure the train and test input data to required format

# %%
# Reshape the training data to 3 dimensional for LSTM input.
X_train = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))

# %%
X_train.shape
# Out:
# (46, 4, 1)

# %%
trainY.shape
# Out:
# (46,)

# %% [markdown]
# The network has a visible layer with 1 input, a hidden layer with 100 LSTM units and then gradually reducing it, and an output layer that makes a single value prediction. The relu activation function is used for the LSTM blocks.

# %%
#create and fit the LSTM network
modelx = Sequential()

#Add first LSTM layer with 20% dropout regularisation
modelx.add(LSTM(units = 100,
                return_sequences = True,
                activation = 'relu',
                input_shape = (X_train.shape[1], 1)))
modelx.add(Dropout(0.3))

#Add Second LSTM Layer
modelx.add(LSTM(units = 95,
                return_sequences = True,
                activation = 'relu'))

#Add Second LSTM Layer
modelx.add(LSTM(units = 95,
                return_sequences = True,
                activation = 'relu'))

#Add Second LSTM Layer
modelx.add(LSTM(units = 90,
                return_sequences = True,
                activation = 'relu'))
modelx.add(Dropout(0.2))
#Add Third LSTM Layer
modelx.add(LSTM(units = 90,
                activation = 'relu'))
modelx.add(Dropout(0.2))

#Add output layer
modelx.add(Dense(1))

# %%
#print model summary
modelx.summary()

#Visualize model architecture
#plot_model(modelx, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 4, 100)            40800
#
#  dropout (Dropout)           (None, 4, 100)            0
#
#  lstm_1 (LSTM)               (None, 4, 95)             74480
#
#  lstm_2 (LSTM)               (None, 4, 95)             72580
#
#  lstm_3 (LSTM)               (None, 4, 90)             66960
#
#  dropout_1 (Dropout)         (None, 4, 90)             0
#
#  lstm_4 (LSTM)               (None, 90)                65160
#
#  dropout_2 (Dropout)         (None, 90)                0
#
#  dense (Dense)               (None, 1)                 91
#
# =================================================================
# Total params: 320,071
# Trainable params: 320,071
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelx.compile(loss='mean_squared_error', optimizer='adam')
history = modelx.fit(X_train,
                     trainY, 
                     epochs = 100, 
                     batch_size = 128, 
                     validation_split = 0.2, 
                     verbose = 1, 
                     shuffle = False)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.3796 - val_loss: 0.1010
# Epoch 2/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.3729 - val_loss: 0.0978
# Epoch 3/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.3666 - val_loss: 0.0943
# Epoch 4/100
# 1/1 [==============================] - 0s 87ms/step - loss: 0.3586 - val_loss: 0.0907
# Epoch 5/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.3508 - val_loss: 0.0868
# Epoch 6/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.3429 - val_loss: 0.0827
# Epoch 7/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.3332 - val_loss: 0.0783
# Epoch 8/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.3241 - val_loss: 0.0738
# Epoch 9/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.3133 - val_loss: 0.0689
# Epoch 10/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.3001 - val_loss: 0.0639
# Epoch 11/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.2878 - val_loss: 0.0586
# Epoch 12/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.2737 - val_loss: 0.0532
# Epoch 13/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2565 - val_loss: 0.0476
# Epoch 14/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2446 - val_loss: 0.0419
# Epoch 15/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.2267 - val_loss: 0.0364
# Epoch 16/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2031 - val_loss: 0.0312
# Epoch 17/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1877 - val_loss: 0.0267
# Epoch 18/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1610 - val_loss: 0.0236
# Epoch 19/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1404 - val_loss: 0.0226
# Epoch 20/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1137 - val_loss: 0.0252
# Epoch 21/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0893 - val_loss: 0.0335
# Epoch 22/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0639 - val_loss: 0.0507
# Epoch 23/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0491 - val_loss: 0.0814
# Epoch 24/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0295 - val_loss: 0.1303
# Epoch 25/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0365 - val_loss: 0.1883
# Epoch 26/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0530 - val_loss: 0.2214
# Epoch 27/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0675 - val_loss: 0.2222
# Epoch 28/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0598 - val_loss: 0.2036
# Epoch 29/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0592 - val_loss: 0.1755
# Epoch 30/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0499 - val_loss: 0.1464
# Epoch 31/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0396 - val_loss: 0.1212
# Epoch 32/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0373 - val_loss: 0.1017
# Epoch 33/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0266 - val_loss: 0.0875
# Epoch 34/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0372 - val_loss: 0.0773
# Epoch 35/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0320 - val_loss: 0.0704
# Epoch 36/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0365 - val_loss: 0.0661
# Epoch 37/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0359 - val_loss: 0.0637
# Epoch 38/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0369 - val_loss: 0.0629
# Epoch 39/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0365 - val_loss: 0.0635
# Epoch 40/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0330 - val_loss: 0.0655
# Epoch 41/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0388 - val_loss: 0.0687
# Epoch 42/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0342 - val_loss: 0.0729
# Epoch 43/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0355 - val_loss: 0.0781
# Epoch 44/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0313 - val_loss: 0.0841
# Epoch 45/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0292 - val_loss: 0.0908
# Epoch 46/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0359 - val_loss: 0.0981
# Epoch 47/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0332 - val_loss: 0.1056
# Epoch 48/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0266 - val_loss: 0.1132
# Epoch 49/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0291 - val_loss: 0.1203
# Epoch 50/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0317 - val_loss: 0.1265
# Epoch 51/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0335 - val_loss: 0.1317
# Epoch 52/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0363 - val_loss: 0.1344
# Epoch 53/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0307 - val_loss: 0.1354
# Epoch 54/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0295 - val_loss: 0.1342
# Epoch 55/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0293 - val_loss: 0.1316
# Epoch 56/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0269 - val_loss: 0.1282
# Epoch 57/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0243 - val_loss: 0.1243
# Epoch 58/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0314 - val_loss: 0.1206
# Epoch 59/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0327 - val_loss: 0.1162
# Epoch 60/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0289 - val_loss: 0.1115
# Epoch 61/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0272 - val_loss: 0.1071
# Epoch 62/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0269 - val_loss: 0.1036
# Epoch 63/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0242 - val_loss: 0.1006
# Epoch 64/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0278 - val_loss: 0.0985
# Epoch 65/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0304 - val_loss: 0.0973
# Epoch 66/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0310 - val_loss: 0.0969
# Epoch 67/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0288 - val_loss: 0.0975
# Epoch 68/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0295 - val_loss: 0.0988
# Epoch 69/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0268 - val_loss: 0.1007
# Epoch 70/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0279 - val_loss: 0.1033
# Epoch 71/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0289 - val_loss: 0.1059
# Epoch 72/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0332 - val_loss: 0.1085
# Epoch 73/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0268 - val_loss: 0.1109
# Epoch 74/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0274 - val_loss: 0.1131
# Epoch 75/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0328 - val_loss: 0.1152
# Epoch 76/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0264 - val_loss: 0.1171
# Epoch 77/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0276 - val_loss: 0.1185
# Epoch 78/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0260 - val_loss: 0.1197
# Epoch 79/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0304 - val_loss: 0.1200
# Epoch 80/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0252 - val_loss: 0.1200
# Epoch 81/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0309 - val_loss: 0.1192
# Epoch 82/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0322 - val_loss: 0.1171
# Epoch 83/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0269 - val_loss: 0.1148
# Epoch 84/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0312 - val_loss: 0.1119
# Epoch 85/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0242 - val_loss: 0.1090
# Epoch 86/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0286 - val_loss: 0.1062
# Epoch 87/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0303 - val_loss: 0.1037
# Epoch 88/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0339 - val_loss: 0.1022
# Epoch 89/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0266 - val_loss: 0.1011
# Epoch 90/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0274 - val_loss: 0.1004
# Epoch 91/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0294 - val_loss: 0.1004
# Epoch 92/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0304 - val_loss: 0.1011
# Epoch 93/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0245 - val_loss: 0.1021
# Epoch 94/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0341 - val_loss: 0.1033
# Epoch 95/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0314 - val_loss: 0.1050
# Epoch 96/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0309 - val_loss: 0.1068
# Epoch 97/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0266 - val_loss: 0.1090
# Epoch 98/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0261 - val_loss: 0.1110
# Epoch 99/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0240 - val_loss: 0.1133
# Epoch 100/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0304 - val_loss: 0.1151

# %%
#Construct Metircs for the LSTM Model
metrics = pd.DataFrame(modelx.history.history)
metrics.head()
# Out:
#        loss  val_loss
# 0  0.379637  0.100965
# 1  0.372933  0.097783
# 2  0.366581  0.094333
# 3  0.358592  0.090665
# 4  0.350841  0.086774

# %%
#Plot the loss of LSTM Model

metrics[['loss', 'val_loss']].plot(figsize=(12,5))
plt.title("Loss vs Val_loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
# Prepare the test data for validation
test_data = scaled_dataset[train_size - look_back: , : ]

#Create the x_test and y_test data sets
X_test = []
y_test =  dataset[train_size : , : ]
for i in range(look_back, len(test_data)):
    X_test.append(test_data[i-look_back:i,0])

# Convert x_test to a numpy array
X_test = np.array(X_test)

# %%
# Prediction with the prepared LSTM model
predicted_BC = modelx.predict(X_test)

# Inverse scaling of predicted values to original scale
predicted_BC = scaler.inverse_transform(predicted_BC)

predicted_BC
# Out:
# array([[0.45215645],
#        [0.45179164],
#        [0.45176092],
#        [0.45247746],
#        [0.4526206 ],
#        [0.45246014]], dtype=float32)

# %% [markdown]
# #### Evaluate Model

# %%
# Determine the Mean Absoulute Error
mae = mean_absolute_error(y_test,predicted_BC)
print("The Mean Absoulte Error is:", round(mae,3))
# Out:
# The Mean Absoulte Error is: 0.011

# %%
# Determine the Root Mean Absoulute Error
from math import sqrt
rmse = sqrt(mean_squared_error(y_test,predicted_BC))
print("Root Mean Square Error is:", round(rmse,3))
# Out:
# Root Mean Square Error is: 0.016

# %%
# Plot the train, predicted and validated data set

train = df_India[:train_size+1]
valid = df_India[train_size:]
valid['Predictions'] = predicted_BC
plt.figure(figsize=(10,5))
plt.title('Predication Biocapacity Per Capita')
plt.xlabel('Date', fontsize=12)
plt.ylabel('BC Per Capita (gha)', fontsize=12)
plt.plot(train['total'])
plt.plot(valid[['total', 'Predictions']])
plt.legend(['Train', 'Valid', 'Predictions'], loc='lower right')
plt.show()

# %%
valid
# Out:
#                total  Predictions
# year
# 2011-01-01  0.452325     0.452156
# 2012-01-01  0.442001     0.451792
# 2013-01-01  0.449335     0.451761
# 2014-01-01  0.449548     0.452477
# 2015-01-01  0.424334     0.452621
# 2016-01-01  0.427524     0.452460

# %% [markdown]
# ### Forecasting CO2 Emissions
#
# Lets observe a forecast iver the entire data set with LSTM model
#
# Since we converted the data into supervised data for a look_back of 4 years, we will  add initial 4 years to prevent data truncation

# %%
#process data to avoid truncation
test_data = df_India.head(4)
test_data = pd.concat([test_data, df_India])
test_data
# Out:
#                total
# year
# 1961-01-01  0.492369
# 1962-01-01  0.486902
# 1963-01-01  0.474522
# 1964-01-01  0.471100
# 1961-01-01  0.492369
# 1962-01-01  0.486902
# 1963-01-01  0.474522
# 1964-01-01  0.471100
# 1965-01-01  0.443812
# 1966-01-01  0.434675
# 1967-01-01  0.459217
# 1968-01-01  0.470072
# 1969-01-01  0.474293
# 1970-01-01  0.492222
# 1971-01-01  0.486564
# 1972-01-01  0.455037
# 1973-01-01  0.472048
# 1974-01-01  0.431216
# 1975-01-01  0.460888
# 1976-01-01  0.453494
# 1977-01-01  0.460989
# 1978-01-01  0.468687
# 1979-01-01  0.437673
# 1980-01-01  0.425475
# 1981-01-01  0.443597
# 1982-01-01  0.429579
# 1983-01-01  0.456280
# 1984-01-01  0.454345
# 1985-01-01  0.440191
# 1986-01-01  0.433295
# 1987-01-01  0.419076
# 1988-01-01  0.443082
# 1989-01-01  0.472557
# 1990-01-01  0.455457
# 1991-01-01  0.450600
# 1992-01-01  0.456813
# 1993-01-01  0.449526
# 1994-01-01  0.455142
# 1995-01-01  0.448806
# 1996-01-01  0.455413
# 1997-01-01  0.448923
# 1998-01-01  0.451125
# 1999-01-01  0.455291
# 2000-01-01  0.439434
# 2001-01-01  0.434697
# 2002-01-01  0.393677
# 2003-01-01  0.422856
# 2004-01-01  0.414923
# 2005-01-01  0.412023
# 2006-01-01  0.416844
# 2007-01-01  0.443574
# 2008-01-01  0.428370
# 2009-01-01  0.410224
# 2010-01-01  0.441753
# 2011-01-01  0.452325
# 2012-01-01  0.442001
# 2013-01-01  0.449335
# 2014-01-01  0.449548
# 2015-01-01  0.424334
# 2016-01-01  0.427524

# %%
#Normalize data 
target = test_data['total']
target_test = test_data.values
test_scaled = scaler.fit_transform(target_test)
test_scaled.shape
# Out:
# (60, 1)

# %%
test = test_scaled[:,:]

# %% [markdown]
# Convert the test data into supervised data for forecasting using built LSTM model

# %%
#convert data
xf_test = []
yf_test = dataset[: , :]

for i in range(look_back, len(test)):
    xf_test.append(test[i-look_back:i, 0])

#convert to a numpy array
xf_test = np.array(xf_test)

# %%
#reshape the data into dimensions of LSTM model
xf_test = xf_test.reshape(xf_test.shape[0], xf_test.shape[1], 1)
xf_test.shape
# Out:
# (56, 4, 1)

# %%
yf_test.shape
# Out:
# (56, 1)

# %%
#predictions of entire dataset using LSTM Model
predicted_BCx = modelx.predict(xf_test)
predicted_BCx = scaler.inverse_transform(predicted_BCx)
predicted_BCx
# Out:
# array([[0.45401138],
#        [0.45377854],
#        [0.45356157],
#        [0.45367217],
#        [0.45401138],
#        [0.4537373 ],
#        [0.4533358 ],
#        [0.45298067],
#        [0.45242688],
#        [0.45252526],
#        [0.45317033],
#        [0.45350003],
#        [0.45371932],
#        [0.45393264],
#        [0.45352906],
#        [0.45291677],
#        [0.4529683 ],
#        [0.45239803],
#        [0.4529706 ],
#        [0.45289454],
#        [0.45300066],
#        [0.45282298],
#        [0.4521189 ],
#        [0.45201746],
#        [0.45234823],
#        [0.45230457],
#        [0.45277685],
#        [0.45255986],
#        [0.45216838],
#        [0.4520005 ],
#        [0.4520398 ],
#        [0.45275638],
#        [0.45318332],
#        [0.45279795],
#        [0.4527368 ],
#        [0.45280853],
#        [0.45269567],
#        [0.452768  ],
#        [0.45268032],
#        [0.45276418],
#        [0.45265415],
#        [0.4526781 ],
#        [0.45255655],
#        [0.4520591 ],
#        [0.45166385],
#        [0.45108443],
#        [0.45158684],
#        [0.45143715],
#        [0.45151022],
#        [0.4517989 ],
#        [0.45215642],
#        [0.4517916 ],
#        [0.4517609 ],
#        [0.45247746],
#        [0.45262063],
#        [0.45246014]], dtype=float32)

# %%
# Plot the original and predicted CO2 emissions set

pd.options.mode.chained_assignment = None 
train = df_India[:]
valid = df_India[:]
valid['Predictions'] = predicted_BCx
plt.figure(figsize=(10,5))
plt.title('Forecasting Per Capita Biocapacity')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Ecological Footprint (gha)', fontsize=12)
plt.plot(train['total'])
plt.plot(valid[['Predictions']])
plt.legend(['Observed', 'Forecasts'], loc='lower right')
plt.show()

# %% [markdown]
# #### Accuracy

# %%
# Accuracy for the entire data set by predicted model
rmse = sqrt(mean_squared_error(yf_test,predicted_BCx))
print("Root Mean Square Error is:", round(rmse,3))
# Out:
# Root Mean Square Error is: 0.021

# %%
#Creare a function to calculate MAPE for our models
def MAPE(pred): 
    return np.mean(np.abs((yf_test - pred) / yf_test)) * 100

print('Mean Absolute Percentage Error is:', round(MAPE(predicted_BCx),3))
# Out:
# Mean Absolute Percentage Error is: 3.728

# %%
valid.tail(4)
# Out:
#                total  Predictions
# year
# 2013-01-01  0.449335     0.451761
# 2014-01-01  0.449548     0.452477
# 2015-01-01  0.424334     0.452621
# 2016-01-01  0.427524     0.452460

# %% [markdown]
# ### Forecasting Future CO2 Emissions
#
# Now lets observe future emissions using the LSTM model

# %%
targetx = dataset

#nomalize data
targetx = scaler.fit_transform(targetx)

#reshape the dataset to be used for input in loop
targetx = targetx.reshape((-1))
targetx.shape
# Out:
# (56,)

# %%
#create a Loop for LSTM input

#here, the new data generated will be used as input fir next year forecast

#look_back is the input year for forecasting

look_back = 4
def predict(n, model):
    pred_list = targetx[-look_back:]
    
    for i in range(n):
        x = pred_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        pred_list = np.append(pred_list, out)
    pred_list = pred_list[look_back-1:]
    
    return pred_list

# for n years of future co2 emissions forecasting

n = 5
forecast5 = predict(n, modelx)

# %%
forecast5
# Out:
# array([0.3429613 , 0.5962585 , 0.59411925, 0.59012496, 0.593267  ,
#        0.59844273], dtype=float32)

# %%
#reshape the forecast for inverse scaling to original values
forecast5 = forecast5.reshape(forecast5.shape[0], 1)
forecast5.shape
# Out:
# (6, 1)

# %%
#inverse scaling to obtain original values
forecast5 = scaler.inverse_transform(forecast5)

# %%
#forecast co2 emissions for next n years
forecast5
# Out:
# array([[0.42752448],
#        [0.45252284],
#        [0.4523117 ],
#        [0.45191753],
#        [0.4522276 ],
#        [0.4527384 ]], dtype=float32)

# %%
#Add to the previous predicted dataset
forecast5 = np.append(predicted_BCx, forecast5)
forecasts = pd.DataFrame(forecast5, columns = ['forecasts'])

# %%
# Plot the original and LSTM forecasting CO2 emissions
data = df_India['1961-01-01':]
train = df_India.values
train = train.astype('float')
train = pd.DataFrame(train, columns = ['total'])
ax = train['total'].plot(label='observed', color='royalblue', legend=True)

#plot forecasted values
forecasts.plot(ax=ax, label='forecasts', color='orangered', alpha=0.9, legend=True)

ax.set_xlabel('Year', size=15)
ax.set_ylabel('Biocapacity Per Capita (t) \n', size=12)
ax.set_title('Future Forecast Biocapacity Per Capita (by 2020) \n', size=14)

plt.legend()
plt.show()

# %% [markdown]
# ***Results Observed***
#
# From the above comparison fo ARIMA, Holt-Winter's and LSTM Model,
#
# >- LSTM Model gives least desirable results with higher RMSE value, We don't further continue as ARIMA and Holt-winter's provides desirable results
#
# >- Comparing the MAPE Scores
#     - LSTM Model : 3.728
#     - ARIMA Model : 2.196
#     - Holt-Winter's Model : 1.837
#
# Thus the Results observed from ***Holt-Winter's Model*** can be inferred further as it is **more accurate*** than LSTM and ARIMA Models

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **tasks**
#
# > - _Modeling_
#     - _ARIMA_
#     - _SARIMA_ (yields similar results to ARIMA)
#     - _Holt's DES_
#     - _Holt-winter's TES_
# > - _Determine best model via RMSE_
# > - _Forecast for target years_
#
# > - _Model Neural Networks_
#     - _LSTM_
# > - _Determine best model via RMSE, MAE, MAPE_
# > - _Forecast for target years_
